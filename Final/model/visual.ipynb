# %%
import pandas as pd
from data import *

# %%
data = pd.read_csv('Data/data.csv')
data.columns = [f'X{i}' for i in range(1, len(data.columns) + 1)]
data = data.iloc[:, 1:] 
data
# Out:
#      X2           X3                 X4                   X5  \
# 0    20  Bhubaneswar               Male  Bachelor's 3rd Year
# 1    69       Liquid               Male  Bachelor's 3rd Year
# 2    20   Faridabad                Male  Bachelor's 3rd Year
# 3    21          UP                Male  Bachelor's 4th Year
# 4    56        Delhi             Female  Bachelor's 2nd Year
# ..   ..          ...                ...                  ...
# 320  21        Bihar               Male  Bachelor's 2nd Year
# 321  20    Jharkhand               Male                 12th
# 322  23       Odisha               Male  Bachelor's 2nd Year
# 323  20       Odisha               Male  Bachelor's 2nd Year
# 324  20          NaN  Prefer not to say  Bachelor's 2nd Year
#
#                    X6         X7         X8                  X9        X10  \
# 0    Computer Science   Everyday      Often         Weight gain      Often
# 1    Computer Science   Everyday   Everyday           No change   Everyday
# 2                 BBA  Sometimes     Rarely           No change         No
# 3                 CSE         No         No           No change         No
# 4                  BA     Rarely     Rarely  Increased appetite     Rarely
# ..                ...        ...        ...                 ...        ...
# 320         Btech Cse  Sometimes  Sometimes           No change         No
# 321            B.tech     Rarely  Sometimes           No change         No
# 322               CSE   Everyday   Everyday         Weight gain  Sometimes
# 323   BTECH 2ND YEAR    Everyday     Rarely         Weight loss      Often
# 324         Btech cse   Everyday   Everyday  Decreased appetite   Everyday
#
#            X11        X12        X13        X14                  X15  \
# 0     Everyday   Everyday   Everyday     Rarely            No change
# 1     Everyday  Sometimes   Everyday   Everyday            No change
# 2           No         No         No         No            No change
# 3           No         No         No         No            No change
# 4       Rarely     Rarely     Rarely     Rarely       Slight decline
# ..         ...        ...        ...        ...                  ...
# 320  Sometimes  Sometimes  Sometimes         No       Slight decline
# 321   Everyday   Everyday         No         No            No change
# 322  Sometimes      Often  Sometimes         No  Significant decline
# 323     Rarely     Rarely         No         No       Slight decline
# 324   Everyday   Everyday  Sometimes  Sometimes  Significant decline
#
#                                                    X16             X17  X18
# 0                                              Nothing             Yes   No
# 1                                                 nope             Yes  Yes
# 2                                                   No              No  Yes
# 3                                                  NaN             Yes  Yes
# 4                                                  NaN              No   No
# ..                                                 ...             ...  ...
# 320                                                 No  I am not sure.   No
# 321  Enjoy your life to the fullest 2 din ki toh zi...              No   No
# 322  Sir, I am lateral entry student having problem...             Yes   No
# 323                                                NO               No   No
# 324  teachers should not cut unnecessary marks in i...  I am not sure.   No
#
# [325 rows x 17 columns]

# %%
import numpy as np
data['X3'] = data['X3'].astype(str)
data['X3'] = data['X3'].str.strip().str.lower()
data['X3'] = data['X3'].replace(replacements)
data['X3'] = data['X3'].apply(lambda x: x.title() if x != 'nan' else np.nan)
data['X3'] = data['X3'].apply(lambda x: x if x in indian_states_ut else 'Others')
print(data['X3'].value_counts())
# Out:
# X3
# Odisha            63
# Bihar             46
# Jharkhand         40
# West Bengal       39
# Maharashtra       36
# Uttar Pradesh     21
# Madhya Pradesh    20
# Delhi             12
# Assam             11
# Haryana            8
# Chhattisgarh       7
# Others             5
# Karnataka          5
# Rajasthan          3
# Andhra Pradesh     2
# Tripura            2
# Gujarat            2
# Goa                1
# Punjab             1
# Tamil Nadu         1
# Name: count, dtype: int64

# %%
def merge_columns(row):
    if row['X18'] == 'Yes':
        return True
    elif row['X17'] == 'Yes':
        return True
    else: 
        return False

data['Output'] = data.apply(merge_columns, axis=1)
data.drop(['X18', 'X17'], axis=1, inplace=True)

data.head()
# Out:
#    X2             X3      X4                   X5                X6  \
# 0  20         Odisha    Male  Bachelor's 3rd Year  Computer Science
# 1  69         Others    Male  Bachelor's 3rd Year  Computer Science
# 2  20        Haryana    Male  Bachelor's 3rd Year               BBA
# 3  21  Uttar Pradesh    Male  Bachelor's 4th Year               CSE
# 4  56          Delhi  Female  Bachelor's 2nd Year                BA
#
#           X7        X8                  X9       X10       X11        X12  \
# 0   Everyday     Often         Weight gain     Often  Everyday   Everyday
# 1   Everyday  Everyday           No change  Everyday  Everyday  Sometimes
# 2  Sometimes    Rarely           No change        No        No         No
# 3         No        No           No change        No        No         No
# 4     Rarely    Rarely  Increased appetite    Rarely    Rarely     Rarely
#
#         X13       X14             X15      X16  Output
# 0  Everyday    Rarely       No change  Nothing    True
# 1  Everyday  Everyday       No change     nope    True
# 2        No        No       No change       No    True
# 3        No        No       No change      NaN    True
# 4    Rarely    Rarely  Slight decline      NaN   False

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns




# Plotting using matplotlib
custom_palette = ["#66c2a5", "#fc8d62"] 
sns.set_palette(custom_palette)

# Plotting using matplotlib
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.countplot(x='X3', hue='Output', data=data)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.xlabel('States')
plt.legend(title='Output', labels=['Not Depressed', 'Depressed'])

plt.subplot(2, 2, 2)
sns.countplot(x='X4', hue='Output', data=data)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.xlabel('Gender')
plt.legend(title='Output', labels=['Not Depressed', 'Depressed'])

plt.subplot(2, 2, 3)
sns.countplot(x='X5', hue='Output', data=data)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.xlabel('Currently In')
plt.legend(title='Output', labels=['Not Depressed', 'Depressed'])

plt.subplot(2, 2, 4)
sns.countplot(x='X2', hue='Output', data=data)
plt.xlabel('Age')
plt.legend(title='Output', labels=['Not Depressed', 'Depressed'])

plt.tight_layout()
plt.show()
