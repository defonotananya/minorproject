# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np

# %%
random_state=42
# Load the data from the CSV file
data = pd.read_csv('Data/encoded_data.csv')

# %%
# Extract features (X) and target variable (y)
X = data.drop(columns=['Output','X16'])  
y = data['Output']  
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# %%
# Initialize the Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=random_state)
# Train the classifier on the training data
random_forest.fit(X_train, y_train)
# Make predictions on the testing data
predictions = random_forest.predict(X_test)
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)
joblib.dump(random_forest, 'Models/random_forest_model.pkl')
# Out:
# Accuracy: 0.9166666666666666
# ['Models/random_forest_model.pkl']

# %%
# Convert the NumPy arrays to float32 for compatibility with TensorFlow
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

# Build the neural network model
NN_model = Sequential()
NN_model.add(Input(shape=(X_train.shape[1],)))  # Input layer with input shape specified
NN_model.add(Dense(128, activation='relu'))  # Hidden layer with 128 neurons and ReLU activation
NN_model.add(Dense(64, activation='relu'))  # Hidden layer with 64 neurons and ReLU activation
NN_model.add(Dense(1, activation='sigmoid'))  # Output layer with 1 neuron and Sigmoid activation for binary classification

# Compile the model
NN_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model on the training data
NN_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

# Make predictions on the testing data
predictions = (NN_model.predict(X_test) > 0.5).astype(int)
NN_model.save('Models/neural_network_model.h5')

# Calculate the accuracy of the model
accuracy = (predictions.flatten() == y_test).mean()
print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.5722 - loss: 0.7606 - val_accuracy: 0.9333 - val_loss: 0.5889
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6644 - loss: 0.6697 - val_accuracy: 0.9333 - val_loss: 0.3592
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6884 - loss: 0.6158 - val_accuracy: 0.9333 - val_loss: 0.3853
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6124 - loss: 0.6342 - val_accuracy: 0.8667 - val_loss: 0.5583
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7254 - loss: 0.6037 - val_accuracy: 0.9333 - val_loss: 0.4314
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6983 - loss: 0.5939 - val_accuracy: 0.9333 - val_loss: 0.3109
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6480 - loss: 0.5867 - val_accuracy: 0.9333 - val_loss: 0.3281
# Epoch 8/100
# ...

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Initialize the SVM classifier with a sigmoid kernel
svm_model = SVC(kernel='sigmoid', random_state=random_state)
# Train the SVM model on the scaled training data
svm_model.fit(X_train_scaled, y_train)
# Make predictions on the testing data
predictions = svm_model.predict(X_test_scaled)
# Calculate the accuracy of the SVM model
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

joblib.dump(svm_model, 'Models/svm_model.joblib')
# Out:
# Accuracy: 0.9166666666666666
# ['Models/svm_model.joblib']
